# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8001/v1", api_key="not-needed")

# 流式输出：stream=True
stream = client.chat.completions.create(
    model="Qwen3-0.6B",
    messages=[
        {"role": "user", "content": "写一首关于春天的五言绝句。"}
    ],
    stream=True,
    max_tokens=200
)

# 逐块接收并打印
for chunk in stream:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="", flush=True)
print()  # 换行
# Out:
# <think>
# 好的，用户让我写一首关于春天的五言绝句。首先，我需要确认五言绝句的基本结构。五言绝句每句五个字，四句组成，通常押韵。春天的主题有很多元素，比如花开、鸟鸣、绿草、燕子等。
#
# 接下来，我得考虑如何将这些元素自然地融合进诗句中。可能需要用一些动词和形容词来描绘春天的景象。比如，第一句可以描述花开，第二句鸟鸣，第三句绿草，第四句夕阳或风。
#
# 然后，押韵的问题。五言绝句通常押平声韵，所以需要选一个合适的韵脚。比如“花”、“鸣”、“草”、“风”或者“云”这样的韵脚。可能需要调整用词，使押韵自然。
#
# 另外，要注意意境的连贯。第一句描绘花开，第二句鸟鸣，第三句绿草，第四句夕阳或
