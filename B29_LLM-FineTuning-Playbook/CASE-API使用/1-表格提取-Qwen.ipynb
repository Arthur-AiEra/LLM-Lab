# %%
import json
import os
from openai import OpenAI

# 注意: 不同地域的 base_url 不通用，请按需选择
# 华北2（北京）: https://dashscope.aliyuncs.com/compatible-mode/v1
# 美国（弗吉尼亚）: https://dashscope-us.aliyuncs.com/compatible-mode/v1
# 新加坡: https://dashscope-intl.aliyuncs.com/compatible-mode/v1
client = OpenAI(
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

# 封装模型响应函数
def get_response(messages):
    response = client.chat.completions.create(
        model="qwen3.5-plus",
        messages=messages,
    )
    return response

# 多模态消息：图片 URL + 文本（OpenAI 兼容格式）
content = [
    {"type": "image_url", "image_url": {"url": "https://aiwucai.oss-cn-huhehaote.aliyuncs.com/pdf_table.jpg"}},
    {"type": "text", "text": "这是一个表格图片，帮我提取里面的内容，输出JSON格式"},
]
messages = [{"role": "user", "content": content}]

# 得到响应
response = get_response(messages)
print(response)
# Out:
# ChatCompletion(id='chatcmpl-a427226b-b9ab-989d-b7da-862ab9ac7e62', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "table_title": "客户投诉处理单",\n  "sections": [\n    {\n      "section_name": "基本信息",\n      "fields": {\n        "客户名称": "",\n        "客诉日期": "",\n        "严重程度": [\n          "一般",\n          "重大"\n        ],\n        "联系方式": "",\n        "回复时间": "",\n        "紧急程度": [\n          "一般",\n          "紧急"\n        ],\n        "产品型号": "",\n        "生产日期": "年    月",\n        "数量": "1",\n        "使用年限": "不详"\n      }\n    },\n    {\n      "section_name": "客户诉求",\n      "fields": {\n        "问题产品追踪": [\n          "客户处",\n          "物流中",\n          "已回厂"\n        ],\n        "客户诉求点": [\n          "退货",\n          "换货",\n          "维修"\n        ],\n        "描述内容": "",\n        "图例说明": "",\n        "描述人/提报人": "",\n        "日期": "2018年__月__日"\n      }\n    },\n    {\n      "section_name": "问题要因分析",\n      "fields": {\n        "分析内容": "",\n        "分析人": "",\n        "日期": "2018年__月__日",\n        "原因归属": [\n          "设计",\n          "可靠性",\n          "品质部",\n          "生产部",\n          "仓储",\n          "运输",\n          "其它"\n        ]\n      }\n    },\n    {\n      "section_name": "零时措施",\n      "fields": {\n        "零时对策建意": "更换液压头，更换阀盘。",\n        "对策方法": [\n          "库存产品再检验",\n          "退回二级供应商",\n          "生产停产纠正",\n          "其它"\n        ]\n      }\n    },\n    {\n      "section_name": "改善措施",\n      "fields": {\n        "防止发生对策": "1、防止发生对策：",\n        "建意人": "",\n        "日期": "2018年__月__日",\n        "要求完成时间": "2018年__月__日",\n        "进程追踪": [\n          "按时完成",\n          "延期完成",\n          "未完成"\n        ]\n      }\n    },\n    {\n      "section_name": "纠正归属",\n      "fields": {\n        "部门归属": [\n          "设计部",\n          "品质部",\n          "装配车间",\n          "压铸车间",\n          "车床车间",\n          "仓库",\n          "运输",\n          "其它"\n        ]\n      }\n    },\n    {\n      "section_name": "备注说明",\n      "fields": {\n        "内容": ""\n      }\n    }\n  ]\n}\n```', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='这个表格是一个质量客诉处理单（8D报告或类似的客户投诉处理表）。我需要将其结构化提取为JSON。\n\n**表格结构分析：**\n1.  **头部信息 (Header Info):** 包含客户名称、客诉日期、严重程度、联系方式、回复时间、紧急程度、产品型号、生产日期、数量、使用年限。\n2.  **客户诉求 (Customer Complaint):** 包含问题产品追踪、客户诉求点、具体的描述区域（左侧是描述人/提报人，右侧是图例说明）。\n3.  **问题要因分析 (Problem Cause Analysis):** 一个大的空白区域用于填写分析，底部有分析人签名和日期，以及原因归属的勾选框。\n4.  **零时措施 (Immediate Actions):** 左侧是零时对策建意（原文写的是“建意”，应该是“建议”），右侧是对策方法（库存再检验、退回二级供应商等）。\n5.  **改善措施 (Corrective Actions):** 包含防止发生对策的填写区域，建意人签名，日期，要求完成时间，进程追踪。\n6.  **纠正归属 (Correction Attribution):** 底部的一行勾选框（设计部、品质部等）。\n7.  **备注说明 (Remarks):** 最底部的区域。\n\n**提取策略：**\n我将按照从上到下、从左到右的顺序提取文本和字段。对于复选框（□），我会保留其文本表示。对于空白填写区，我会用空字符串或占位符表示。\n\n**JSON 结构设计：**\n根对象包含几个主要部分：\n- `basic_info`: 基础信息部分。\n- `complaint_details`: 客户诉求部分。\n- `cause_analysis`: 问题要因分析部分。\n- `immediate_actions`: 零时措施部分。\n- `corrective_actions`: 改善措施部分。\n- `attribution`: 归属部分。\n- `remarks`: 备注。\n\n**详细提取过程：**\n\n*   **Row 1:** 客户名称, 客诉日期, 严重程度 (□一般 □重大)\n*   **Row 2:** 联系方式, 回复时间, 紧急程度 (□一般 □紧急)\n*   **Row 3:** 产品型号, 生产日期 (年 月), 数量 (1), 使用年限 (不详)\n*   **Row 4:** 客户诉求 (合并单元格), 问题产品追踪 (□客户处 □物流中 □已回厂)\n*   **Row 5:** (客户诉求下方), 客户诉求点 (□退货 □换货 □维修)\n*   **Row 6 (Main Body):** 左侧是大片空白（描述人/提报人: 2018年__月__日），右侧是“图例说明”。\n*   **Row 7:** 问题要因分析 (左侧竖排标题), 右侧大片空白，底部有 分析人: 2018年__月__日\n*   **Row 8:** 原因归属: □设计 □可靠性 □品质部 □生产部 □仓储 □运输 □其它\n*   **Row 9:** 零时措施 (左侧竖排标题), 零时对策建意: 更换液压头，更换阀盘。 | 对策方法 (右侧竖排标题) -> □库存产品再检验, □退回二级供应商, □生产停产纠正, □其它\n*   **Row 10:** 改善措施 (左侧竖排标题), 1、防止发生对策: (大片空白) -> 底部: 建意人: 日期: 2018年__月__日\n*   **Row 11:** (改善措施下方) 要求完成时间: 2018年__月__日 进程追踪: □按时完成 □延期完成 □未完成\n*   **Row 12:** 纠正归属: □设计部 □品质部 □装配车间 □压铸车间 □车床车间 □仓库 □运输 □其它\n*   **Row 13:** 备注说明 (左侧竖排标题), 右侧空白。\n\n**修正与优化：**\n- 注意原文中的错别字，如“建意”应为“建议”，但在JSON中我尽量保持原文或标注。为了准确性，我将按图片原文提取（即“建意”）。\n- 日期部分有很多下划线，表示待填写。\n\n开始构建JSON。'))], created=1773811026, model ...

# %%
# 输出内容
print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "table_title": "客户投诉处理单",
#   "sections": [
#     {
#       "section_name": "基本信息",
#       "fields": {
#         "客户名称": "",
#         "客诉日期": "",
#         "严重程度": [
#           "一般",
#           "重大"
#         ],
#         "联系方式": "",
#         "回复时间": "",
#         "紧急程度": [
#           "一般",
#           "紧急"
#         ],
#         "产品型号": "",
#         "生产日期": "年    月",
#         "数量": "1",
#         "使用年限": "不详"
#       }
#     },
#     {
#       "section_name": "客户诉求",
#       "fields": {
#         "问题产品追踪": [
#           "客户处",
#           "物流中",
#           "已回厂"
#         ],
#         "客户诉求点": [
#           "退货",
#           "换货",
#           "维修"
#         ],
#         "描述内容": "",
#         "图例说明": "",
#         "描述人/提报人": "",
#         "日期": "2018年__月__日"
#       }
#     },
#     {
#       "section_name": "问题要因分析",
#       "fields": {
#         "分析内容": "",
#         "分析人": "",
#         "日期": "2018年__月__日",
#         "原因归属": [
#           "设计",
#           "可靠性",
#           "品质部",
#           "生产部",
#           "仓储",
#           "运输",
#           "其它"
#         ]
#       }
#     },
#     {
#       "section_name": "零时措施",
#       "fields": {
#         "零时对策建意": "更换液压头，更换阀盘。",
#         "对策方法": [
#           "库存产品再检验",
#           "退回二级供应商",
#           "生产停产纠正",
#           "其它"
#         ]
#       }
#     },
#     {
#       "section_name": "改善措施",
#       "fields": {
#         "防止发生对策": "1、防止发生对策：",
#         "建意人": "",
#         "日期": "2018年__月__日",
#         "要求完成时间": "2018年__月__日",
#         "进程追踪": [
#           "按时完成",
#           "延期完成",
#           "未完成"
#         ]
#       }
#     },
#     {
#       "section_name": "纠正归属",
#       "fields": {
#         "部门归属": [
#           "设计部",
#           "品质部",
#           "装配车间",
#           "压铸车间",
#           "车床车间",
#           "仓库",
#           "运输",
#           "其它"
#         ]
#       }
#     },
#     {
#       "section_name": "备注说明",
#       "fields": {
#         "内容": ""
#       }
#     }
#   ]
# }
# ```
